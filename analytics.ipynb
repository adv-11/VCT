# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/vct-champions.csv')
df
# Out:
#        player team  rnd  rating    acs    kd  kast    adr   kpr   apr  fkpr  \
# 0       trexx  VIT  151    1.23  228.0  1.24  0.72  155.0  0.81  0.34  0.09
# 1       Derke  FNC  293    1.22  257.4  1.33  0.72  167.0  0.92  0.18  0.17
# 2     primmie  TLN   85    1.22  243.0  1.32  0.74  152.4  0.88  0.27  0.08
# 3   Chronicle  FNC  293    1.21  224.4  1.23  0.73  153.8  0.77  0.29  0.13
# 4      keznit  KRÜ  156    1.18  250.8  1.16  0.76  170.7  0.83  0.33  0.14
# ..        ...  ...  ...     ...    ...   ...   ...    ...   ...   ...   ...
# 75    Boaster  FNC  293    0.71  122.2  0.68  0.70   76.9  0.43  0.32  0.06
# 76       Life  FPX  115    0.71  175.8  0.78  0.61  116.3  0.60  0.14  0.13
# 77      Lakia  GEN  153    0.61  118.3  0.56  0.69   79.5  0.39  0.30  0.05
# 78   Yosemite  BLG   78    0.61  127.0  0.52  0.55   84.8  0.40  0.23  0.05
# 79       Crws  TLN   85    0.51  133.8  0.57  0.61   91.2  0.45  0.24  0.05
#
#     fdpr    hs   cls  kmax    k    d   a  fk  fd
# ...
